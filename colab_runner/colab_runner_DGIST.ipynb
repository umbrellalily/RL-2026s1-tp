# %% [markdown]
# # 배터리 환경 — 정해진 글자 배열 학습 + 바람 robustness (Colab Runner)
#
# **환경**: `BatteryShapeFormationEnv` 한 종류만 사용. 바람 유무는 `--wind-prob/--randomize-wind` 옵션으로 한 스크립트(`comm_train_battery.py`)에서 처리.
#
# **두 정책을 한 노트북에서 학습**:
# - **A (battery)**: 배터리 제약만, 바람 없음
# - **B (battery + wind robust)**: 배터리 제약 + 바람 도메인 랜덤화 `[0, WIND_PROB]`
#
# **산출물 (모두 Drive 직저장)**:
# - ckpts / TensorBoard runs
# - GIF (각 정책 + 바람 0 / 바람 EVAL_WIND_PROB)
# - eval txt (각 정책)
# - 바람 sweep PNG (A vs B 비교 곡선)
#
# **런타임 끊김 대응**: 셀 6의 `latest_ckpt()` 헬퍼가 Drive를 보고 두 정책 각각의 최신 ckpt를 자동 감지. 학습 셀(8/9) 그대로 다시 실행하면 끊긴 지점부터 이어짐.
#
# **런타임**: `런타임 → 런타임 유형 변경 → GPU (T4)` 필수.
#
# **한쪽만 학습하고 싶을 때**: 셀 8(=A) 또는 셀 9(=B) 중 원하는 쪽만 실행하면 됨. 평가/스윕 셀은 양쪽 ckpt가 다 있어야 동작.

# %% [markdown]
# ## 1. GitHub clone
#
# 복구 시에도 이 셀만 다시 돌리면 OK. Drive 저장된 ckpt/log는 그대로 살아있음.

# %%
BRANCH = "Saehoon"

# 어떤 %cd 상태에서 다시 돌려도 깨끗이 다시 받도록 절대경로 사용.
# (상대경로 + 이미 CWD가 /content/RL-2026s1-tp 안인 경우 RL-2026s1-tp/RL-2026s1-tp/ 가
# 중첩 생성되는 버그 회피.)
# %cd /content
# !rm -rf /content/RL-2026s1-tp
# !git clone https://github.com/umbrellalily/RL-2026s1-tp.git /content/RL-2026s1-tp
# %cd /content/RL-2026s1-tp

# !git fetch origin
# !git switch $BRANCH
# !git pull origin $BRANCH

# !git log --oneline -1
# !grep -n 'start.iter' comm_train_battery.py | head -3 || echo '⚠️ --start-iter 코드 없음 — 코드 동기화 확인 필요'
# !grep -n 'wind_prob' comm_train_battery.py | head -3 || echo '⚠️ wind 인자 없음 — 코드 동기화 확인 필요\'
# Out:
# /content
# Cloning into '/content/RL-2026s1-tp'...
# remote: Enumerating objects: 219, done.
# remote: Counting objects: 100% (219/219), done.
# remote: Compressing objects: 100% (175/175), done.
# remote: Total 219 (delta 80), reused 175 (delta 36), pack-reused 0 (from 0)
# Receiving objects: 100% (219/219), 19.18 MiB | 18.74 MiB/s, done.
# Resolving deltas: 100% (80/80), done.
# /content/RL-2026s1-tp
# Branch 'Saehoon' set up to track remote branch 'Saehoon' from 'origin'.
# Switched to a new branch 'Saehoon'
# From https://github.com/umbrellalily/RL-2026s1-tp
#  * branch            Saehoon    -> FETCH_HEAD
# Already up to date.
# 566c850 (HEAD -> Saehoon, origin/Saehoon) maxstep 개선 runner
# 244:        "--start-iter",
# 250:            "folder with incrementing ckpt numbers (e.g. --start-iter 110 → next save is "
# 442:        global_iter = args.start_iter + it + 1
# 56:    wind_prob: float,
# 78:        wind_prob=wind_prob,
# 286:        wind_prob=args.wind_prob,

# %% [markdown]
# ## 2. Google Drive 마운트 + 저장 경로
#
# 모든 산출물은 `DRIVE_ROOT` 아래로 직저장. 시퀀스를 바꿔 가며 학습하려면 셀 4의 `EXP_TAG`만 바꾸면 됨 → A/B 둘 다 별도 폴더로 자동 분리.

# %%
from google.colab import drive
drive.mount("/content/drive")

DRIVE_ROOT = "/content/drive/MyDrive/drone_results/battery_letters_DGIST"
# !mkdir -p {DRIVE_ROOT}/ckpts {DRIVE_ROOT}/runs {DRIVE_ROOT}/gifs {DRIVE_ROOT}/evals {DRIVE_ROOT}/sweeps
print("DRIVE_ROOT =", DRIVE_ROOT)
# !ls -la {DRIVE_ROOT}
# Out:
# Mounted at /content/drive
# DRIVE_ROOT = /content/drive/MyDrive/drone_results/battery_letters_DGIST
# total 20
# drwx------ 2 root root 4096 May 29 08:27 ckpts
# drwx------ 2 root root 4096 May 29 08:27 evals
# drwx------ 2 root root 4096 May 29 08:27 gifs
# drwx------ 2 root root 4096 May 29 08:27 runs
# drwx------ 2 root root 4096 May 29 08:27 sweeps

# %% [markdown]
# ## 3. 패키지 설치

# %%
# !pip install -q torchrl pettingzoo==1.24.3 gymnasium scipy matplotlib pillow tensorboard
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 847.8/847.8 kB 29.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 82.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 537.6/537.6 kB 42.5 MB/s eta 0:00:00

# %% [markdown]
# ## 4. 학습 시퀀스 + 환경/학습/바람 설정
#
# **시퀀스 한 번에 하나만 학습** (random sampling 없음). 다른 시퀀스는 `EXP_TAG`를 바꿔서 별도로.
#
# 예시: `GROUND→B→A→Y→C` (4단계). 단계가 늘수록 `MAX_STEPS`/`TOTAL_FRAMES` 키우기.
#
# **바람 설정**: `WIND_PROB=0.3` → 정책 B 학습 시 매 에피소드 바람 세기 `[0, 0.3]`·방향 랜덤. 평가용 고정 바람은 `EVAL_WIND_PROB`.

# %%
# ============================================================
# 학습/평가 공통 설정
# ============================================================
TARGET_SEQUENCE = "GROUND,D,G,I,S,T"        # ← 학습/평가 시퀀스 (자유 변경)
EXP_TAG         = "DGIST"                # ← Drive 폴더명에 들어감

# 환경
GRID_SIZE = 25
N_AGENTS  = 14
MAX_STEPS = 500                       # 단계당 ~100 step 권장

# 학습 hyperparam (양쪽 정책 공통)
TOTAL_FRAMES     = 1_200_000
FRAMES_PER_BATCH = 4096
MINIBATCH_SIZE   = 512
PPO_EPOCHS       = 6
LR               = 2e-4
ENT_COEF         = 0.01
CLIP_EPS         = 0.15
CKPT_EVERY       = 5                  # disconnection 시 최대 손실 ~5 iter

# Battery hyperparam (양쪽 정책 공통)
INITIAL_BATTERY          = 1.0
HOVER_BATTERY_COST       = 0.002
MOVE_BATTERY_COST        = 0.005
LOW_BATTERY_MOVE_PENALTY = 0.15

# Reward shaping (양쪽 정책 공통)
COMPLETION_REWARD       = 50.0
ASSIGNED_TARGET_REWARD  = 0.1
COVERAGE_DELTA_REWARD   = 0.3
HOVER_PENALTY           = 0.05
SHAPING_COEF            = 0.5

# 바람 hyperparam (정책 B 학습 / 평가에서 사용)
WIND_PROB      = 0                  # B 학습 시 바람 상한
WIND_STRENGTH  = 0
EVAL_WIND_PROB = 0                  # GIF/eval 시 B에 거는 고정 바람
WIND_LEVELS    = "0.0,0.0,0.0,0.0,0.-"  # sweep용

# A→B 전이학습 옵션 (B를 처음부터 학습하지 않고 A의 정책에서 finetune)
B_INIT_FROM_A           = True            # True면 B를 A의 ckpt에서 warm-start (B 자체 ckpt 없을 때만 적용)
B_FINETUNE_LR           = 1e-4            # finetune 시 LR (사전학습 정책 보호용으로 낮춤)
B_FINETUNE_ENT_COEF     = 0.005           # finetune 시 entropy (탐험 줄임)
B_FINETUNE_TOTAL_FRAMES = 500_000         # finetune 은 from-scratch 보다 짧게

# Drive 경로 (A=battery only, B=battery + wind robust)
SAVE_DIR_A   = f"{DRIVE_ROOT}/ckpts/{EXP_TAG}_battery"
SAVE_DIR_B   = f"{DRIVE_ROOT}/ckpts/{EXP_TAG}_battery_wind" + ("_from_A" if B_INIT_FROM_A else "")
TB_LOGDIR_A  = f"{DRIVE_ROOT}/runs/{EXP_TAG}_battery"
TB_LOGDIR_B  = f"{DRIVE_ROOT}/runs/{EXP_TAG}_battery_wind" + ("_from_A" if B_INIT_FROM_A else "")
GIF_A        = f"{DRIVE_ROOT}/gifs/demo_{EXP_TAG}_battery.gif"
GIF_B        = f"{DRIVE_ROOT}/gifs/demo_{EXP_TAG}_battery_wind.gif"
EVAL_TXT_A   = f"{DRIVE_ROOT}/evals/eval_{EXP_TAG}_battery.txt"
EVAL_TXT_B   = f"{DRIVE_ROOT}/evals/eval_{EXP_TAG}_battery_wind.txt"
SWEEP_PNG    = f"{DRIVE_ROOT}/sweeps/wind_sweep_{EXP_TAG}_battery.png"

print(f"TARGET_SEQUENCE = {TARGET_SEQUENCE}")
print(f"SAVE_DIR_A      = {SAVE_DIR_A}")
print(f"SAVE_DIR_B      = {SAVE_DIR_B}")
print(f"GIF_A / GIF_B   = {GIF_A} | {GIF_B}")
print(f"SWEEP_PNG       = {SWEEP_PNG}")
# Out:
# TARGET_SEQUENCE = GROUND,D,G,I,S,T
# SAVE_DIR_A      = /content/drive/MyDrive/drone_results/battery_letters_DGIST/ckpts/DGIST_battery
# SAVE_DIR_B      = /content/drive/MyDrive/drone_results/battery_letters_DGIST/ckpts/DGIST_battery_wind_from_A
# GIF_A / GIF_B   = /content/drive/MyDrive/drone_results/battery_letters_DGIST/gifs/demo_DGIST_battery.gif | /content/drive/MyDrive/drone_results/battery_letters_DGIST/gifs/demo_DGIST_battery_wind.gif
# SWEEP_PNG       = /content/drive/MyDrive/drone_results/battery_letters_DGIST/sweeps/wind_sweep_DGIST_battery.png

# %% [markdown]
# ## 5. Smoke test
#
# 환경이 지정한 시퀀스로 reset되는지 + 바람 옵션이 살아있는지 빠르게 확인.

# %%
# %cd /content/RL-2026s1-tp

from comm_env import BatteryShapeFormationEnv

shapes = [s.strip() for s in TARGET_SEQUENCE.split(',') if s.strip()]

for tag, wp, randw in [("battery (no wind)", 0.0, False),
                        ("battery + wind DR", WIND_PROB, True)]:
    env = BatteryShapeFormationEnv(
        grid_size=GRID_SIZE, n_agents=N_AGENTS, max_steps=MAX_STEPS,
        shapes=shapes,
        initial_battery=INITIAL_BATTERY,
        hover_battery_cost=HOVER_BATTERY_COST,
        move_battery_cost=MOVE_BATTERY_COST,
        low_battery_move_penalty=LOW_BATTERY_MOVE_PENALTY,
        wind_prob=wp, wind_strength=WIND_STRENGTH, randomize_wind=randw,
    )
    obs, _ = env.reset(seed=0)
    print(f"[{tag}] path={env.formation_path.label} | stages={len(env.formation_path.targets)} | obs_dim={env.obs_dim}")
# Out:
# /content/RL-2026s1-tp
# [battery (no wind)] path=GROUND->D->G->I->S->T | stages=5 | obs_dim=85
# [battery + wind DR] path=GROUND->D->G->I->S->T | stages=5 | obs_dim=85

# %% [markdown]
# ## 6. Resume helper — Drive에 있는 마지막 ckpt 찾기
#
# 셀 8 (정책 A) / 셀 9 (정책 B) 학습이 이 결과를 보고 자동으로 warm-start 여부를 결정.
#
# 런타임 끊긴 뒤에는 셀 1~4 재실행 → 이 셀 → 셀 8/9 그대로 재실행이면 끊긴 지점부터 이어짐.

# %%
import os, re, glob

def latest_ckpt(save_dir):
    """Return (path, effective_iter) of the truly-latest ckpt in save_dir.

    Scans save_dir itself, plus any legacy `{save_dir}_resume_from_N` folders
    from before this notebook used continuous iter numbering. For ckpts inside
    a `_resume_from_N` folder, the effective iter is `N + filename_iter`,
    so the latest across all folders wins and training can continue with
    incrementing global iter numbers in the main folder.
    """
    cand = []
    # Main folder: effective iter == filename iter
    for p in glob.glob(os.path.join(save_dir, 'ckpt_*.pt')):
        m = re.search(r'ckpt_(\d+)\.pt$', p)
        if m:
            cand.append((int(m.group(1)), p))
    # Legacy resume folders: effective iter = N + filename iter
    for d in glob.glob(f"{save_dir}_resume_from_*"):
        m = re.search(r'_resume_from_(\d+)$', d)
        if not m: continue
        base = int(m.group(1))
        for p in glob.glob(os.path.join(d, 'ckpt_*.pt')):
            mm = re.search(r'ckpt_(\d+)\.pt$', p)
            if mm:
                cand.append((base + int(mm.group(1)), p))
    if not cand:
        return None, 0
    cand.sort()
    return cand[-1][1], cand[-1][0]   # (path, effective_iter)

A_RESUME_CKPT, A_RESUME_ITER = latest_ckpt(SAVE_DIR_A)
B_RESUME_CKPT, B_RESUME_ITER = latest_ckpt(SAVE_DIR_B)

for label, ck, it in [("A (battery)",      A_RESUME_CKPT, A_RESUME_ITER),
                       ("B (battery+wind)", B_RESUME_CKPT, B_RESUME_ITER)]:
    if ck:
        print(f"[{label}] 이어 학습할 ckpt: {ck} (effective iter {it})")
    else:
        print(f"[{label}] ckpt 없음 → 처음부터 학습")
# Out:
# [A (battery)] 이어 학습할 ckpt: /content/drive/MyDrive/drone_results/battery_letters_DGIST/ckpts/DGIST_battery/ckpt_80.pt (effective iter 80)
# [B (battery+wind)] ckpt 없음 → 처음부터 학습

# %% [markdown]
# ## 7. (선택) 빠른 파이프라인 검증
#
# 본 학습 전, GROUND→X 소규모 실행으로 정상 동작만 확인 (수 분). reward 곡선만 확인.

# %%
# %cd /content/RL-2026s1-tp
# !python comm_train_battery.py --shapes GROUND,X --max-steps 250 \
  --total-frames 50000 --frames-per-batch 4096 \
  --wind-prob 0.3 --randomize-wind \
  --ckpt-every 5 --save-dir /tmp/ckpt_smoke_batt_wind --tb-logdir /tmp/runs_smoke_batt_wind
# Out:
# /content/RL-2026s1-tp
# 2026-05-29 09:50:52.705240: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Battery training: grid_size=25, n_agents=14, max_steps=250, obs_dim=85, shapes='GROUND->X'
# Battery: initial=1.0, hover_cost=0.002, move_cost=0.005, low_battery_move_penalty=0.1
# Wind: prob=0.3, strength=1, randomize=True
# /usr/local/lib/python3.12/dist-packages/torchrl/collectors/_base.py:1188: DeprecationWarning: SyncDataCollector has been deprecated and will be removed in v0.13. Please use Collector instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchrl/collectors/_single.py:906: UserWarning: total_frames (50000) is not exactly divisible by frames_per_batch (4096). This means 3248 additional frames will be collected.To silence this message, set the environment variable RL_WARNINGS to False.
#   warnings.warn(
# TensorBoard logging -> /tmp/runs_smoke_batt_wind/shape_comm20_battery_1780048263
# 2026-05-29 09:51:51,310 [torchrl][INFO]    Initialized LazyTensorStorage with torch.Size([4096]) shape [END]
# /usr/local/lib/python3.12/dist-packages/torchrl/objectives/ppo.py:1248: UserWarning: You requested advantage normalization and the advantage key has more dimensions than the tensordict batch. Make sure to pass `normalize_advantage_exclude_dims` if you want to keep any dimension independent while computing normalization statistics. If you are working in multi-agent/multi-objective settings this is highly suggested.
#   warnings.warn(
# iter=   1  frames=    4096  mean_ep_reward=-21.475  success= 0.0%  loss= 0.1142
# iter=   2  frames=    8192  mean_ep_reward=-18.720  success= 0.0%  loss= 0.1220
# iter=   3  frames=   12288  mean_ep_reward=-16.449  success= 0.0%  loss= 0.1057
# iter=   4  frames=   16384  mean_ep_reward=-14.351  success= 0.0%  loss= 0.1006
# object address  : 0x7bf837a893c0
# object refcount : 3
# object type     : 0xa284e0
# object type name: KeyboardInterrupt
# object repr     : KeyboardInterrupt()
# lost sys.stderr

# %% [markdown]
# ## 8. 정책 A 학습 — 배터리만 (바람 없음)
#
# Resume 시에도 **같은 폴더** (`SAVE_DIR_A`) 에 계속 저장. 새 ckpt는 마지막 effective iter 다음 번호부터 (예: 마지막이 `ckpt_210.pt` → 다음은 `ckpt_215.pt`, `ckpt_220.pt`, ...).

# %%
# %cd /content/RL-2026s1-tp
A_RESUME_CKPT = SAVE_DIR_A + "/ckpt_75.pt"
import os
A_load_arg = ""
A_start_iter = 0
if A_RESUME_CKPT:
    A_load_arg = f"--load-ckpt {A_RESUME_CKPT}"
    A_start_iter = A_RESUME_ITER
    print(f"RESUME [A] from iter {A_start_iter}: {A_RESUME_CKPT}")
    print(f"  -> 같은 폴더에 ckpt_{A_start_iter + CKPT_EVERY}.pt 부터 누적 저장")
else:
    print(f"FRESH START [A] -> {SAVE_DIR_A}")

os.makedirs(SAVE_DIR_A, exist_ok=True)

# !python comm_train_battery.py \
  --grid-size {GRID_SIZE} --n-agents {N_AGENTS} --max-steps {MAX_STEPS} \
  --shapes "{TARGET_SEQUENCE}" \
  --completion-reward {COMPLETION_REWARD} \
  --assigned-target-reward {ASSIGNED_TARGET_REWARD} \
  --coverage-delta-reward {COVERAGE_DELTA_REWARD} \
  --hover-penalty {HOVER_PENALTY} --shaping-coef {SHAPING_COEF} \
  --initial-battery {INITIAL_BATTERY} \
  --hover-battery-cost {HOVER_BATTERY_COST} \
  --move-battery-cost {MOVE_BATTERY_COST} \
  --low-battery-move-penalty {LOW_BATTERY_MOVE_PENALTY} \
  --total-frames {TOTAL_FRAMES} \
  --frames-per-batch {FRAMES_PER_BATCH} \
  --minibatch-size {MINIBATCH_SIZE} --ppo-epochs {PPO_EPOCHS} \
  --lr {LR} --ent-coef {ENT_COEF} --clip-eps {CLIP_EPS} \
  --ckpt-every {CKPT_EVERY} \
  --start-iter {A_start_iter} \
  --save-dir {SAVE_DIR_A} \
  --tb-logdir {TB_LOGDIR_A} \
  {A_load_arg}
# Out:
# /content/RL-2026s1-tp
# RESUME [A] from iter 80: /content/drive/MyDrive/drone_results/battery_letters_DGIST/ckpts/DGIST_battery/ckpt_75.pt
#   -> 같은 폴더에 ckpt_85.pt 부터 누적 저장
# 2026-05-29 09:57:49.508892: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Battery training: grid_size=25, n_agents=14, max_steps=500, obs_dim=85, shapes='GROUND->D->G->I->S->T'
# Battery: initial=1.0, hover_cost=0.002, move_cost=0.005, low_battery_move_penalty=0.15
# Warm-started from /content/drive/MyDrive/drone_results/battery_letters_DGIST/ckpts/DGIST_battery/ckpt_75.pt
# /usr/local/lib/python3.12/dist-packages/torchrl/collectors/_base.py:1188: DeprecationWarning: SyncDataCollector has been deprecated and will be removed in v0.13. Please use Collector instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchrl/collectors/_single.py:906: UserWarning: total_frames (1200000) is not exactly divisible by frames_per_batch (4096). This means 128 additional frames will be collected.To silence this message, set the environment variable RL_WARNINGS to False.
#   warnings.warn(
# TensorBoard logging -> /content/drive/MyDrive/drone_results/battery_letters_DGIST/runs/DGIST_battery/shape_comm20_battery_1780048675
# 2026-05-29 09:58:41,306 [torchrl][INFO]    Initialized LazyTensorStorage with torch.Size([4096]) shape [END]
# /usr/local/lib/python3.12/dist-packages/torchrl/objectives/ppo.py:1248: UserWarning: You requested advantage normalization and the advantage key has more dimensions than the tensordict batch. Make sure to pass `normalize_advantage_exclude_dims` if you want to keep any dimension independent while computing normalization statistics. If you are working in multi-agent/multi-objective settings this is highly suggested.
#   warnings.warn(
# iter=  81  frames=  331776  mean_ep_reward=+30.124  success= 0.0%  loss= 0.4092
# iter=  82  frames=  335872  mean_ep_reward=+29.306  success= 0.0%  loss= 0.3878
# iter=  83  frames=  339968  mean_ep_reward=+33.051  success= 0.0%  loss= 0.4250
# iter=  84  frames=  344064  mean_ep_reward=+35.969  success= 0.0%  loss= 0.4259
# iter=  85  frames=  348160  mean_ep_reward=+38.651  success= 0.0%  loss= 0.4253
# iter=  86  frames=  352256  mean_ep_reward=+41.957  success= 0.0%  loss= 0.4030
# iter=  87  frames=  356352  mean_ep_reward=+37.303  success= 0.0%  loss= 0.4153
# iter=  88  frames=  360448  mean_ep_reward=+46.786  success= 0.0%  loss= 0.3918
# iter=  89  frames=  364544  mean_ep_reward=+43.595  success= 0.0%  loss= 0.4245
# iter=  90  frames=  368640  mean_ep_reward=+53.029  success= 0.0%  loss= 0.6147
# iter=  91  frames=  372736  mean_ep_reward=+50.748  success= 0.0%  loss= 0.3764
# iter=  92  frames=  376832  mean_ep_reward=+48.647  success= 0.0%  loss= 0.3809
# iter=  93  frames=  380928  mean_ep_reward=+54.066  success= 0.0%  loss= 0.4931
# iter=  94  frames=  385024  mean_ep_reward=+54.278  success= 0.0%  loss= 0.3551
# iter=  95  frames=  389120  mean_ep_reward=+66.527  success= 0.0%  loss= 0.5474
# iter=  96  frames=  393216  mean_ep_reward=+60.468  success= 0.0%  loss= 0.5439
# iter=  97  frames=  397312  mean_ep_reward=+66.045  success= 0.0%  loss= 0.6130
# iter=  98  frames=  401408  mean_ep_reward=+61.132  success= 0.0%  loss= 0.4108
# iter=  99  frames=  405504  mean_ep_reward=+70.865  success= 0.0%  loss= 0.6883
# iter= 100  frames=  409600  mean_ep_reward=+66.232  success= 0.0%  loss= 0.4242
# iter= 101  frames=  413696  mean_ep_reward=+84.864  success= 0.0%  loss= 0.8480
# iter= 102  frames=  417792  mean_ep_reward=+88.431  success= 0.0%  loss= 0.8336
# iter= 103  frames=  421888  mean_ep_reward=+88.794  success= 0.0%  loss= 0.9123
# iter= 104  frames=  425984  mean_ep_reward=+87.857  success= 0.0%  loss= 0.7533
# iter= 105  frames=  430080  mean_ep_reward=+98.488  success= 0.0%  loss= 0.9942
# iter= 106  frames=  434176  mean_ep_reward=+99.150  success= 0.0%  loss= 1.0046
# iter= 107  frames=  438272  mean_ep_reward=+98.486  success= 0.0%  loss= 0.9145
# iter= 108  frames=  442368  mean_ep_reward=+104.094  success= 0.0%  loss= 1.0460
# iter= 109  frames=  446464  mean_ep_reward=+103.961  success= 0.0%  loss= 0.9236
# iter= 110  frames=  450560  mean_ep_reward=+100.073  success= 0.0%  loss= 0.9571
# iter= 111  frames=  454656  mean_ep_reward=+110.377  success= 0.0%  loss= 0.9141
# iter= 112  frames=  458752  mean_ep_reward=+103.475  success= 0.0%  loss= 0.8351
# iter= 113  frames=  462848  mean_ep_reward=+112.187  success= 0.0%  loss= 1.1082
# iter= 114  frames=  466944  mean_ep_reward=+108.965  success= 0.0%  loss= 0.8057
# iter= 115  frames=  471040  mean_ep_reward=+116.380  success= 0.0%  loss= 1.0654
# iter= 116  frames=  475136  mean_ep_reward=+123.455  success= 0.0%  loss= 1.1513
# iter= 117  frames=  479232  mean_ep_reward=+122.828  success= 0.0%  loss= 0.9551
# iter= 118  frames=  483328  mean_ep_reward=+119.017  success= 0.0%  loss= 0.9660
# iter= 119  frames=  487424  mean_ep_reward=+132.658  success= 0.0%  loss= 1.3345
# iter= 120  frames=  491520  mean_ep_reward=+127.835  success= 0.0%  loss= 1.1610
# iter= 121  frames=  495616  mean_ep_reward=+142.964  success= 0.0%  loss= 1.2970
# iter= 122  frames=  499712  mean_ep_reward=+144.318  success= 0.0%  loss= 1.3936
# iter= 123  frames=  503808  mean_ep_reward=+136.878  success= 0.0%  loss= 1.3493
# iter= 124  frames=  507904  mean_ep_reward=+147.983  success= 0.0%  loss= 1.3324
# iter= 125  frames=  512000  mean_ep_reward=+161.848  success= 0.0%  loss= 1.6409
# iter= 126  frames=  516096  mean_ep_reward=+157.719  success= 0.0%  loss= 1.4601
# iter= 127  frames=  520192  mean_ep_reward=+162.413  success= 0.0%  loss= 1.6050
# iter= 128  frames=  524288  mean_ep_reward=+169.807  success= 0.0%  loss= 1.6565
# iter= 129  frames=  528384  mean_ep_reward=+131.210  success= 0.0%  loss= 1.2621
# iter= 130  frames=  532480  mean_ep_reward=+196.998  success= 0.0%  loss= 1.9243
# iter= 131  frames=  536576  mean_ep_reward=+184.644  success= 0.0%  loss= 2.0646
# iter= 132  frames=  540672  mean_ep_reward=+184.358  success= 0.0%  loss= 1.9647
# iter= 133  frames=  544768  mean_ep_reward=+186.787  success= 0.0%  loss= 1.7953
# iter= 134  frames=  548864  mean_ep_reward=+189.797  success= 0.0%  loss= 2.0133
# iter= 135  frames=  552960  mean_ep_reward=+201.911  success= 0.0%  loss= 2.1592
# iter= 136  frames=  557056  mean_ep_reward=+194.439  success= 0.0%  loss= 2.0186
# iter= 137  frames=  561152  mean_ep_reward=+199.058  success= 0.0%  loss= 2.0021
# iter= 138  frames=  565248  mean_ep_reward=+204.382  success= 0.0%  loss= 2.1018
# iter= 139  frames=  569344  mean_ep_reward=+208.234  success= 0.0%  loss= 2.2529
# iter= 140  frames=  573440  mean_ep_reward=+209.840  success= 0.0%  loss= 1.9194
# iter= 141  frames=  577536  mean_ep_reward=+202.551  success= 0.0%  loss= 2.0291
# iter= 142  frames=  581632  mean_ep_reward=+203.319  success= 0.0%  loss= 2.0486
# iter= 143  frames=  585728  mean_ep_reward=+198.682  success= 0.0%  loss= 1.9476
# iter= 144  frames=  589824  mean_ep_reward=+193.345  success= 0.0%  loss= 2.0119
# iter= 145  frames=  593920  mean_ep_reward=+189.245  success= 0.0%  loss= 2.0320
# iter= 146  frames=  598016  mean_ep_reward=+183.167  success= 0.0%  loss= 1.7360
# iter= 147  frames=  602112  mean_ep_reward=+207.979  success= 0.0%  loss= 1.9520
# iter= 148  frames=  606208  mean_ep_reward=+211.997  success= 0.0%  loss= 1.9252
# iter= 149  frames=  610304  mean_ep_reward=+206.404  success= 0.0%  loss= 2.0665
# iter= 150  frames=  614400  mean_ep_reward=+217.707  success= 0.0%  loss= 1.8119
# iter= 151  frames=  618496  mean_ep_reward=+219.662  success= 0.0%  loss= 2.0693
# iter= 152  frames=  622592  mean_ep_reward=+209.472  success= 0.0%  loss= 1.7893
# iter= 153  frames=  626688  mean_ep_reward=+224.119  success= 0.0%  loss= 2.2484
# iter= 154  frames=  630784  mean_ep_reward=+213.647  success= 0.0%  loss= 1.8534
# iter= 155  frames=  634880  mean_ep_reward=+192.282  success= 0.0%  loss= 2.0020
# iter= 156  frames=  638976  mean_ep_reward=+222.821  success= 0.0%  loss= 2.0136
# iter= 157  frames=  643072  mean_ep_reward=+225.181  success= 0.0%  loss= 2.0815
# iter= 158  frames=  647168  mean_ep_reward=+212.518  success= 0.0%  loss= 1.8988
# iter= 159  frames=  651264  mean_ep_reward=+224.990  success= 0.0%  loss= 2.1160
# iter= 160  frames=  655360  mean_ep_reward=+218.016  success= 0.0%  loss= 1.9203
# iter= 161  frames=  659456  mean_ep_reward=+230.415  success= 0.0%  loss= 2.1508
# iter= 162  frames=  663552  mean_ep_reward=+235.496  success= 0.0%  loss= 2.2581
# iter= 163  frames=  667648  mean_ep_reward=+230.439  success= 0.0%  loss= 2.0792
# iter= 164  frames=  671744  mean_ep_reward=+238.283  success= 0.0%  loss= 2.0775
# iter= 165  frames=  675840  mean_ep_reward=+232.417  success= 0.0%  loss= 2.0645
# iter= 166  frames=  679936  mean_ep_reward=+251.226  success= 0.0%  loss= 2.2397
# iter= 167  frames=  684032  mean_ep_reward=+243.041  success= 0.0%  loss= 2.1742
# iter= 168  frames=  688128  mean_ep_reward=+249.866  success= 0.0%  loss= 2.2568
# iter= 169  frames=  692224  mean_ep_reward=+251.042  success= 0.0%  loss= 2.2504
# iter= 170  frames=  696320  mean_ep_reward=+259.493  success=25.0%  loss= 2.3981
# iter= 171  frames=  700416  mean_ep_reward=+229.388  success= 0.0%  loss= 1.9909
# iter= 172  frames=  704512  mean_ep_reward=+271.433  success=22.2%  loss= 2.6914
# iter= 173  frames=  708608  mean_ep_reward=+272.037  success=25.0%  loss= 2.4935
# iter= 174  frames=  712704  mean_ep_reward=+267.946  success=11.1%  loss= 2.4150
# iter= 175  frames=  716800  mean_ep_reward=+276.448  success=22.2%  loss= 2.8404
# iter= 176  frames=  720896  mean_ep_reward=+287.875  success=37.5%  loss= 2.8841
# iter= 177  frames=  724992  mean_ep_reward=+275.253  success=22.2%  loss= 2.4142
# iter= 178  frames=  729088  mean_ep_reward=+295.339  success=55.6%  loss= 3.0658
# iter= 179  frames=  733184  mean_ep_reward=+253.056  success=33.3%  loss= 2.9010
# iter= 180  frames=  737280  mean_ep_reward=+283.160  success=58.3%  loss= 3.6848
# iter= 181  frames=  741376  mean_ep_reward=+276.376  success=60.0%  loss= 3.4543
# iter= 182  frames=  745472  mean_ep_reward=+217.357  success=12.5%  loss= 2.1678
# iter= 183  frames=  749568  mean_ep_reward=+252.822  success=50.0%  loss= 3.6723
# iter= 184  frames=  753664  mean_ep_reward=+279.907  success=33.3%  loss= 2.8362
# iter= 185  frames=  757760  mean_ep_reward=+275.443  success=55.6%  loss= 3.1741
# iter= 186  frames=  761856  mean_ep_reward=+222.142  success= 0.0%  loss= 2.0492
# iter= 187  frames=  765952  mean_ep_reward=+217.870  success= 0.0%  loss= 2.1241
# iter= 188  frames=  770048  mean_ep_reward=+249.454  success= 0.0%  loss= 2.4768
# iter= 189  frames=  774144  mean_ep_reward=+297.237  success=70.0%  loss= 3.4230
# iter= 190  frames=  778240  mean_ep_reward=+274.702  success=25.0%  loss= 2.5778
# iter= 191  frames=  782336  mean_ep_reward=+237.256  success= 0.0%  loss= 2.5233
# iter= 192  frames=  786432  mean_ep_reward=+298.895  success=55.6%  loss= 3.2434
# iter= 193  frames=  790528  mean_ep_reward=+249.777  success= 0.0%  loss= 2.3626
# iter= 194  frames=  794624  mean_ep_reward=+281.840  success=25.0%  loss= 2.8623
# iter= 195  frames=  798720  mean_ep_reward=+292.976  success=63.6%  loss= 3.4430
# iter= 196  frames=  802816  mean_ep_reward=+302.231  success=100.0%  loss= 4.9164
# iter= 197  frames=  806912  mean_ep_reward=+298.126  success=84.6%  loss= 4.1293
# iter= 198  frames=  811008  mean_ep_reward=+306.460  success=100.0%  loss= 4.8457
# iter= 199  frames=  815104  mean_ep_reward=+302.082  success=93.8%  loss= 4.8008
# iter= 200  frames=  819200  mean_ep_reward=+305.443  success=100.0%  loss= 4.8107
# iter= 201  frames=  823296  mean_ep_reward=+307.920  success=92.3%  loss= 4.0943
# iter= 202  frames=  827392  mean_ep_reward=+311.498  success=90.9%  loss= 3.6865
# iter= 203  frames=  831488  mean_ep_reward=+292.474  success=85.7%  loss= 4.1271
# iter= 204  frames=  835584  mean_ep_reward=+310.536  success=100.0%  loss= 4.1286
# iter= 205  frames=  839680  mean_ep_reward=+306.225  success=83.3%  loss= 3.9139
# iter= 206  frames=  843776  mean_ep_reward=+312.269  success=100.0%  loss= 3.8722
# iter= 207  frames=  847872  mean_ep_reward=+305.320  success=100.0%  loss= 4.6990
# iter= 208  frames=  851968  mean_ep_reward=+289.748  success=85.7%  loss= 3.9231
# iter= 209  frames=  856064  mean_ep_reward=+302.527  success=100.0%  loss= 4.9691
# iter= 210  frames=  860160  mean_ep_reward=+305.243  success=100.0%  loss= 4.3921
# iter= 211  frames=  864256  mean_ep_reward=+321.268  success=90.0%  loss= 3.2105
# iter= 212  frames=  868352  mean_ep_reward=+302.365  success=100.0%  loss= 4.7709
# iter= 213  frames=  872448  mean_ep_reward=+303.207  success=100.0%  loss= 4.7876
# iter= 214  frames=  876544  mean_ep_reward=+301.170  success=93.8%  loss= 4.3495
# iter= 215  frames=  880640  mean_ep_reward=+302.902  success=100.0%  loss= 4.9272
# iter= 216  frames=  884736  mean_ep_reward=+299.624  success=100.0%  loss= 4.5836
# iter= 217  frames=  888832  mean_ep_reward=+299.692  success=100.0%  loss= 4.8237
# iter= 218  frames=  892928  mean_ep_reward=+297.212  success=94.1%  loss= 4.2266
# iter= 219  frames=  897024  mean_ep_reward=+302.328  success=100.0%  loss= 4.3700
# iter= 220  frames=  901120  mean_ep_reward=+304.125  success=100.0%  loss= 4.2334
# iter= 221  frames=  905216  mean_ep_reward=+300.316  success=84.6%  loss= 3.6293
# iter= 222  frames=  909312  mean_ep_reward=+299.434  success=76.9%  loss= 3.3466
# iter= 223  frames=  913408  mean_ep_reward=+305.262  success=91.7%  loss= 3.2843
# iter= 224  frames=  917504  mean_ep_reward=+297.931  success=63.6%  loss= 3.3215
# iter= 225  frames=  921600  mean_ep_reward=+305.383  success=92.3%  loss= 3.7147
# iter= 226  frames=  925696  mean_ep_reward=+302.301  success=100.0%  loss= 4.4918
# iter= 227  frames=  929792  mean_ep_reward=+297.716  success=94.1%  loss= 4.1821
# iter= 228  frames=  933888  mean_ep_reward=+297.723  success=88.2%  loss= 4.2088

# %% [markdown]
# ## 9. 정책 B 학습 — 배터리 + 바람 도메인 랜덤화 `[0, WIND_PROB]`
#
# **모드는 자동 결정** (셀 4의 `B_INIT_FROM_A` 토글):
# - `B_RESUME_CKPT` 있음 → B 자체 ckpt에서 resume (같은 폴더, iter 번호 누적)
# - `B_INIT_FROM_A=True` + A ckpt 있음 → **A의 정책에서 finetune** (LR/entropy/frames는 `B_FINETUNE_*` 값으로 override). 결과는 `..._battery_wind_from_A` 폴더에 저장, iter 카운트는 0부터
# - 그 외 → from scratch
#
# Finetune은 from-scratch 대비 학습량을 절반 이하로 줄여도 보통 빨리 수렴함. (A가 이미 포메이션 로직을 알고 있으니 B는 바람 보정만 추가로 학습)

# %%
# %cd /content/RL-2026s1-tp

import os
B_lr           = LR
B_ent          = ENT_COEF
B_total_frames = TOTAL_FRAMES
B_load_arg     = ""
B_start_iter   = 0

if B_RESUME_CKPT:
    B_load_arg = f"--load-ckpt {B_RESUME_CKPT}"
    B_start_iter = B_RESUME_ITER
    print(f"RESUME [B] from iter {B_start_iter}: {B_RESUME_CKPT}")
    print(f"  -> 같은 폴더({SAVE_DIR_B}) 에 ckpt_{B_start_iter + CKPT_EVERY}.pt 부터 누적 저장")
elif B_INIT_FROM_A:
    assert A_RESUME_CKPT, "B_INIT_FROM_A=True 인데 A 의 ckpt가 없음. 먼저 셀 8 (정책 A) 학습 필요."
    B_load_arg = f"--load-ckpt {A_RESUME_CKPT}"
    B_lr           = B_FINETUNE_LR
    B_ent          = B_FINETUNE_ENT_COEF
    B_total_frames = B_FINETUNE_TOTAL_FRAMES
    print(f"FINETUNE [B] from A: {A_RESUME_CKPT} -> {SAVE_DIR_B}")
    print(f"  override: lr={B_lr}, ent_coef={B_ent}, total_frames={B_total_frames}")
    print(f"  iter 카운트는 0부터 (A 와 별개 학습)")
else:
    print(f"FRESH START [B] -> {SAVE_DIR_B}")

os.makedirs(SAVE_DIR_B, exist_ok=True)

# !python comm_train_battery.py \
  --grid-size {GRID_SIZE} --n-agents {N_AGENTS} --max-steps {MAX_STEPS} \
  --shapes "{TARGET_SEQUENCE}" \
  --completion-reward {COMPLETION_REWARD} \
  --assigned-target-reward {ASSIGNED_TARGET_REWARD} \
  --coverage-delta-reward {COVERAGE_DELTA_REWARD} \
  --hover-penalty {HOVER_PENALTY} --shaping-coef {SHAPING_COEF} \
  --initial-battery {INITIAL_BATTERY} \
  --hover-battery-cost {HOVER_BATTERY_COST} \
  --move-battery-cost {MOVE_BATTERY_COST} \
  --low-battery-move-penalty {LOW_BATTERY_MOVE_PENALTY} \
  --wind-prob {WIND_PROB} --wind-strength {WIND_STRENGTH} --randomize-wind \
  --total-frames {B_total_frames} \
  --frames-per-batch {FRAMES_PER_BATCH} \
  --minibatch-size {MINIBATCH_SIZE} --ppo-epochs {PPO_EPOCHS} \
  --lr {B_lr} --ent-coef {B_ent} --clip-eps {CLIP_EPS} \
  --ckpt-every {CKPT_EVERY} \
  --start-iter {B_start_iter} \
  --save-dir {SAVE_DIR_B} \
  --tb-logdir {TB_LOGDIR_B} \
  {B_load_arg}

# %% [markdown]
# ## 10. TensorBoard
#
# 양쪽 정책의 학습 곡선을 동시에 확인.

# %%
# %load_ext tensorboard
# %tensorboard --logdir {DRIVE_ROOT}/runs

# %% [markdown]
# ## 11. 평가에 쓸 최신 ckpt 자동 선택
#
# 셀 6의 `latest_ckpt`를 다시 호출해서 A/B 각각의 (resume 폴더 포함) 가장 늦은 ckpt를 골라 평가용 변수로 잡음. 원하는 다른 iter 가 있으면 `CKPT_A`/`CKPT_B`를 직접 덮어써도 됨.

# %%
CKPT_A, _ = latest_ckpt(SAVE_DIR_A)
CKPT_B, _ = latest_ckpt(SAVE_DIR_B)
assert CKPT_A, f"No A ckpt found under {SAVE_DIR_A}*"
assert CKPT_B, f"No B ckpt found under {SAVE_DIR_B}*"
print(f"A (battery)      ckpt: {CKPT_A}")
print(f"B (battery+wind) ckpt: {CKPT_B}")

# %% [markdown]
# ## 12. 정책 A 평가 — 바람 없는 환경에서 GIF + 통계 (Drive 저장)

# %%
# %cd /content/RL-2026s1-tp
# !python comm_eval_battery.py \
  --ckpt {CKPT_A} \
  --grid-size {GRID_SIZE} --n-agents {N_AGENTS} --max-steps {MAX_STEPS} \
  --shapes "{TARGET_SEQUENCE}" \
  --completion-reward {COMPLETION_REWARD} \
  --initial-battery {INITIAL_BATTERY} \
  --hover-battery-cost {HOVER_BATTERY_COST} \
  --move-battery-cost {MOVE_BATTERY_COST} \
  --low-battery-move-penalty {LOW_BATTERY_MOVE_PENALTY} \
  --greedy --n-episodes 50 \
  --save-gif {GIF_A} \
  --out {EVAL_TXT_A}

print('\n=== eval txt 결과 (A: battery, no wind) ===')
# !cat {EVAL_TXT_A}

# %% [markdown]
# ## 13. 정책 B 평가 — `EVAL_WIND_PROB` 바람 속 GIF + 통계 (Drive 저장)

# %%
# %cd /content/RL-2026s1-tp
# !python comm_eval_battery.py \
  --ckpt {CKPT_B} \
  --grid-size {GRID_SIZE} --n-agents {N_AGENTS} --max-steps {MAX_STEPS} \
  --shapes "{TARGET_SEQUENCE}" \
  --completion-reward {COMPLETION_REWARD} \
  --initial-battery {INITIAL_BATTERY} \
  --hover-battery-cost {HOVER_BATTERY_COST} \
  --move-battery-cost {MOVE_BATTERY_COST} \
  --low-battery-move-penalty {LOW_BATTERY_MOVE_PENALTY} \
  --wind-prob {EVAL_WIND_PROB} \
  --greedy --n-episodes 50 \
  --save-gif {GIF_B} \
  --out {EVAL_TXT_B}

print('\n=== eval txt 결과 (B: battery + wind) ===')
# !cat {EVAL_TXT_B}

# %% [markdown]
# ## 14. 바람 sweep — A vs B robustness 곡선 PNG
#
# `wind_sweep_battery.py`가 두 정책을 `WIND_LEVELS` 각 점에서 평가하고 비교 곡선 PNG를 Drive에 저장. 곡선이 갈수록 벌어지면 B(바람 DR 학습)가 robust한 것.

# %%
# %cd /content/RL-2026s1-tp
# !python wind_sweep_battery.py \
  --ckpt-a {CKPT_A} --ckpt-b {CKPT_B} \
  --shapes "{TARGET_SEQUENCE}" --max-steps {MAX_STEPS} \
  --wind-levels {WIND_LEVELS} --n-episodes 100 \
  --completion-reward {COMPLETION_REWARD} \
  --initial-battery {INITIAL_BATTERY} \
  --hover-battery-cost {HOVER_BATTERY_COST} \
  --move-battery-cost {MOVE_BATTERY_COST} \
  --low-battery-move-penalty {LOW_BATTERY_MOVE_PENALTY} \
  --label-a "battery (no wind)" --label-b "battery + wind DR" \
  --out {SWEEP_PNG}

from IPython.display import Image
Image(SWEEP_PNG)

# %% [markdown]
# ## 15. GIF 표시 (A: 바람 없음 / B: 바람 속)

# %%
from IPython.display import Image, display
print('=== A (battery only, no wind) ===')
display(Image(GIF_A))
print('=== B (battery + wind) ===')
display(Image(GIF_B))

# %% [markdown]
# ## 16. Drive 산출물 점검
#
# 새 세션 복구 시 이 셀로 "지금 Drive에 뭐가 남아있나"만 확인하면 그대로 이어갈 수 있음.

# %%
print("=== 모든 실험 ckpt 폴더 ===")
# !ls -la {DRIVE_ROOT}/ckpts/

print(f"\n=== 현재 실험 ({EXP_TAG}) A (battery) ckpt 폴더들 ===")
# !for d in {DRIVE_ROOT}/ckpts/{EXP_TAG}_battery*; do echo "  $d:"; ls $d 2>/dev/null | sort -t_ -k2 -n | tail -5; done

print("\n=== sweeps ===")
# !ls -la {DRIVE_ROOT}/sweeps/ 2>/dev/null

print("\n=== gifs ===")
# !ls -la {DRIVE_ROOT}/gifs/ 2>/dev/null

print("\n=== evals ===")
# !ls -la {DRIVE_ROOT}/evals/ 2>/dev/null

# %% [markdown]
# ---
#
# ## 런타임 끊겼을 때 복구 절차
#
# 1. 새 GPU 런타임 할당
# 2. 셀 1 (clone) → 셀 2 (Drive mount) → 셀 3 (pip) → 셀 4 (설정 재확인) 만 다시 실행
# 3. 셀 6 (resume helper)로 A/B 각각 Drive에 어디까지 학습됐는지 확인
# 4. 셀 8 (A) / 셀 9 (B) 중 끊긴 쪽 다시 실행 → 자동으로 마지막 ckpt에서 이어 학습
# 5. 양쪽 학습이 끝나면 셀 11 → 셀 12 → 셀 13 → 셀 14 (sweep)
#
# **중요**: `CKPT_EVERY` 가 작을수록 disconnection 시 손실이 적음 (기본 5 iter).
#
# ## 새 시퀀스를 추가로 학습하고 싶을 때
#
# 셀 4의 `TARGET_SEQUENCE` 와 `EXP_TAG`를 바꾸고 셀 6 → 8 → 9 → 11 → 12 → 13 → 14 를 다시 실행. `EXP_TAG`가 다르면 별도 폴더에 저장되므로 기존 학습이 덮이지 않음.
#
# ## 한쪽 정책만 학습하고 싶을 때
#
# - A(배터리만)만: 셀 8 → (셀 11에서 `CKPT_B = None` 처리 필요) → 셀 12. 셀 14 sweep은 둘 다 있어야 의미가 있어서 skip.
# - B(배터리+바람)만: 셀 9 → (셀 11 동일) → 셀 13. sweep 역시 skip.
